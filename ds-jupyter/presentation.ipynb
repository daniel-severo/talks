# %% [markdown]
# ![Jupyter](logo.png)
# # <center>Open source, data science interativo e computação científica em mais de 40 linguagens de programação!</center>

# %% [markdown]
# # <center>Roda diretamente no seu navegador !</center>
# ![Jupyter Preview](http://jupyter.org/assets/jupyterpreview.png)

# %% [markdown]
# # <center>Easy as py.</center>

# %%
# imports.
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# define variables.
x = np.linspace(0, 4*np.pi, 100)
y = np.sin(x)

# plots!
plt.plot(x,y)
plt.show()

# %% [markdown]
# # <center>Podemos fazer melhor?</center>

# %%
# add some flavor.
π = np.pi #\pi

# %%
# redefine
x = np.linspace(0, 4*π, 100)

# %%
# plot again
plt.style.use('ggplot')
plt.figure(figsize=(16,6))
plt.plot(x,y)
plt.show()

# %% [markdown]
# # <center>Comandos mágicos!</center>

# %% [markdown]
# ### Teste de Desempenho

# %%
# %time import pandas
# Out:
# CPU times: user 120 ms, sys: 12 ms, total: 132 ms
# Wall time: 132 ms

# %%
# %%timeit
for n in range(1000):
    n = n+(n-1)
# Out:
# 10000 loops, best of 3: 63.3 µs per loop

# %%
import random
# %prun x = [random.random() for i in range(int(1e6))]

# %% [markdown]
# ![Jupyter](prun_output.png)

# %% [markdown]
# ### LaTeX

# %%
# %%latex
# $$\vec{\nabla}\times\vec{E}=\frac{\partial\vec{B}}{\partial t}$$
# Out:
# $$\vec{\nabla}\times\vec{E}=\frac{\partial\vec{B}}{\partial t}$$

# %% [markdown]
# ### E mais!

# %%
# !wget "http://2016.pythonbrasil.org.br/"
# Out:
# --2016-04-12 14:33:43--  http://2016.pythonbrasil.org.br/
# Resolving 2016.pythonbrasil.org.br (2016.pythonbrasil.org.br)... 199.27.76.133
# Connecting to 2016.pythonbrasil.org.br (2016.pythonbrasil.org.br)|199.27.76.133|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23984 (23K) [text/html]
# Saving to: ‘index.html.3’
#
# 100%[======================================>] 23,984       120KB/s   in 0.2s
#
# 2016-04-12 14:33:44 (120 KB/s) - ‘index.html.3’ saved [23984/23984]
